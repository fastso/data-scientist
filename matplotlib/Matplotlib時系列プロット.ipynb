# %%
import pandas as pd

df = pd.read_csv('csv/Matplotlib時系列プロット.csv', parse_dates=['date'], index_col='date')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

# Add the time-series for "relative_temp" to the plot
ax.plot(df.index, df['value01'])

ax.set_xlabel('Date')
ax.set_ylabel('Value01')
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

df_zoom_in = df['2021-01-01':'2021-01-05']

ax.plot(df_zoom_in.index, df_zoom_in["value01"])

plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(df.index, df['value01'])
ax.plot(df.index, df['value02'])
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

# Initalize a Figure and Axes
fig, ax = plt.subplots()

# Plot the CO2 variable in blue
ax.plot(df.index, df['value01'], color='b')

# Create a twin Axes that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature in red
ax2.plot(df.index, df['value02'], color='r')
plt.xticks(rotation=90)
plt.show()

# %%
# Define a function called plot_timeseries
def plot_timeseries(axes, x, y, color, xlabel, ylabel):
    # Plot the inputs x,y in the provided color
    axes.plot(x, y, color=color)

    # Set the x-axis label
    axes.set_xlabel(xlabel)

    # Set the y-axis label
    axes.set_ylabel(ylabel, color=color)

    # Set the colors tick params for y-axis
    axes.tick_params('y', colors=color)

# %%
fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, df.index, df['value01'], 'blue', 'Date',
                'Value01')

# Create a twin Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, df.index, df['value02'], 'red',
                'Date', 'Value02')
plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots()
plot_timeseries(ax, df.index, df['value01'], 'blue', 'Date',
                'Value01')
ax2 = ax.twinx()
plot_timeseries(ax2, df.index, df['value02'], 'red',
                'Date', 'Value02')

ax2.annotate('annotate day', xy=(pd.Timestamp('2021-01-10'), 900),
             xytext=(pd.Timestamp('2021-01-10'), 200),
             arrowprops={'arrowstyle': '->', 'color': 'gray'})
plt.xticks(rotation=90)
plt.show()
